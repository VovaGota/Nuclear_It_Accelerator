# %% [markdown]
# <h2>Рассмотрение влияния слабой нелинейности линз в периодическом канале на динамику пучка</h2>
#
# <img src="FO_Channel.jpg" alt="drawing" width="600"/>
#
# Пусть электронно-оптический канал состоит из периодической последовательности тонких фокусирующих линз (FO канал). Фокусное расстояние линз одинаково и равно $f$, расстояние между линзами $d$. Пусть эти линзы обладают слабой сферической аберрацией. Рассмотрим, как данная нелинейность будет влиять на динамику пучка.
#
# Примем, что пучок на входе в канал на фазовой плоскости представляется равномерно заполненным эллипсом, ориентированным по главным осям. При линейном движении эллипс переходит в эллипс, причём он всегда остаётся внутри описанного вокруг него эллипса Флоке, который обладает свойством переходить сам в себя через каждый период. Т.е., если рассматривать фазовый портрет пучка в последовательности точек через период, он будет как-бы вращаться внутри эллипса Флоке.
#
# Наличине аберрации приводит к более сильному, чем надо, возрастанию силы линз на краях пучка и, следовательно, к более быстрому набегу фазы бетатронных колебаний для крайних частиц. При слабой нелинейности такие частицы будут оставаться внутри описанного эллипса Флоке, но будут вращаться внутри него с большей угловой скоростью. Это приводит к "нитеобразованию", и спустя какое-то время пучок более-менее полностью заполняет собой эллипс Флоке.
#
# Данный процесс, естественно, сопровождается ростом среднеквадратичного эмиттанса.
#
# Для начала построим массив точек, равномерно заполняющих какой-либо эллипс, (пусть он будет ориентирован по главным осям). Вычислим среднеквадратичный эмиттанс данного распределения, сравним его с теоретическим.

# %%
import numpy as np
import holoviews as hv
hv.extension('bokeh')

#Размеры начального эллипса и число точек в нём
ax = 7.07107
ay = 2.23607
N = 2500

#Берём и расставляем (с небольшим запасом) точки по прямоугольной области так,
#чтобы в начальный эллипс попало указаное ранее число точек
#Здесь мы расставилит точки случайным образом, хотя прямоугольную область можно было легко заполнить равномерно
N1 = int(N*4/3.14*1.1)
x = np.random.uniform(low=-ax, high=ax, size=N1)
y = np.random.uniform(low=-ay, high=ay, size=N1)

def ini_ell(x,y):
    return (x/ax)**2 + (y/ay)**2

#Из всех точек формируем массив тех точек, которые находятся внутри начального эллипса
#Обрезаем этот массив до указанного размера
P0 = [[x[k],y[k]] for k in range(N1) if ini_ell(x[k],y[k]) <=1]
if len(P0) > N:
    P0=P0[:N]
N=len(P0)

#Выводим точки
dots1 = hv.Points((P0)).opts(title="Ininial ellipse")
dots1.redim(x=hv.Dimension("x", range=(-5.5, 5.5)), y=hv.Dimension("x'", range=(-5.5, 5.5)))
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#   > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
# ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='48bff8fb-082a-4512-984e-7c13f5421936'>
#   <div id="a2b4debe-f10b-42bf-9771-f7eaed583ab2" data-root-id="48bff8fb-082a-4512-984e-7c13f5421936" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"d60199b3-b772-4713-a078-24875b790a9e":{"version":"3.8.2","title":"Bokeh Application","config":{"type":"object","name":"DocumentConfig","id":"03eb6688-0bb1-493d-9593-b97505133234","attributes":{"notifications":{"type":"object","name":"Notifications","id":"36c147d2-6f02-4f8b-8240-5d251f8d9c18"}}},"roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"48bff8fb-082a-4512-984e-7c13f5421936"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"84a3399b-5d7b-4a04-a9f4-fce38f4cda3f","attributes":{"plot_id":"48bff8fb-082a-4512-984e-7c13f5421936","comm_id":"2b9a7bf638924a18b907f82d5200249f","client_comm_id":"214dd09891544715b4f1c598ae379948"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"start","kind":"Any","default":0},{"name":"end","kind":"Any","default":100},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"ReactiveESM1","properties":[{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"JSComponent1","properties":[{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"ReactComponent1","properties":[{"name":"use_shadow_dom","kind":"Any","default":true},{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"AnyWidgetComponent1","properties":[{"name":"use_shadow_dom","kind":"Any","default":true},{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"max_notifications","kind":"Any","default":5},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"n ...
#   var render_items = [{"docid":"d60199b3-b772-4713-a078-24875b790a9e","roots":{"48bff8fb-082a-4512-984e-7c13f5421936":"a2b4debe-f10b-42bf-9771-f7eaed583ab2"},"root_ids":["48bff8fb-082a-4512-984e-7c13f5421936"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(version);
#     } else if (root.Bokeh.version === version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# <div class="logo-block">
# <a href="https://holoviews.org" target="_blank" title="HoloViews 1.22.1">
#   <img src='...' style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
# </a>
#
#
# <a href="https://bokeh.org" target="_blank" title="Bokeh 3.8.2">
#   <img src='data:image/png;base64,...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'>
#   </img>
# </a>
#
#
#
#
#
#
#
# <span style="float: left; margin-left: 5px; line-height: 15px; cursor: pointer; opacity: 0.7;"
#       onmouseover="this.style.opacity='1'"
#       onmouseout="this.style.opacity='0.7'"
#       title="Extension loaded. This cell output contains code that enables plot interactivity, it should not be removed.">ⓘ</span>
# </div>
# :Points   [x,x']

# %%
#Функция расчёта среднеквадратичного эмиттанса
def calc_eps_rms(P):
    X2 = 0
    XY = 0
    Y2 = 0
    for k in range(N):
        x = P[k][0]
        y = P[k][1]
        X2 += x*x
        XY += x*y
        Y2 += y*y
    rms2 = (X2*Y2 - XY*XY)/(N**2)
    return np.sqrt(rms2)

#Вывод среднеквадратичного эмиттанса начального распределения
print("Inintial eps_rms = ",calc_eps_rms(P0))
print("Theoretical eps = ", ax*ay)
# Out:
# Inintial eps_rms =  3.929234889009373
# Theoretical eps =  15.811407494899997

# %% [markdown]
# <div class = "alert alert-block alert-info">
# Как видно, среднеквадратичный и обычный эмиттансы начального распределения связаны между собой коэффициентом 4.
# </div>

# %% [markdown]
# ***Расчёт параметров эллипса Флоке***
#
# Для более красивой иллюстрации изучаемого явления положим такую силу линз без учёта аберрации, что набег фазы бетатронных колебаний на один преиод составляет $\pi/4$. Тогда в случае линейного движения через каждые четыре оборота эллипс должен переходить сам в себя.
#
# Расчитаем параметры начального эллипса Флоке. Пусть начальная точка находится непосредственно перед линзой. Тогда матрица перехода на период вперед будет равна
# $$
# M =
# \begin{pmatrix}
# 1 & d \\
# 0 & 1 \\
# \end{pmatrix}
# \begin{pmatrix}
# 1 & 0 \\
# -1/f & 1 \\
# \end{pmatrix}=
# \begin{pmatrix}
# 1-d/f & d \\
# -1/f & 1 \\
# \end{pmatrix}.
# $$
#
# Тогда, с одно стороны, косинус набега фазы бетатронных колебаний на период будет равен
# $$
# \DeclareMathOperator{\Tr}{Tr}
# \cos{\mu}=\frac{1}{2}\Tr\left(M\right)=1-\frac{1}{2}d/f.
# $$
# Отсюда находим силу линз для заданного $\mu$:
# $$
# d/f=2\left(1-\cos{\mu}\right).
# $$
#
#
# С другой стороны, эта матрица выражается через параметры Твисса
# $$
# M=
# \begin{pmatrix}
# \cos{\mu}+\alpha\sin{\mu} & \beta\sin{\mu} \\
# -\gamma\sin{\mu} & \cos{\mu}-\alpha\sin{\mu} \\
# \end{pmatrix}.
# $$
# Отсюда находим эти параметры
# $$
# \beta/d=1/\sin{\mu},
# $$
# $$
# \gamma=1/f\sin{\mu},
# $$
# $$
# \alpha=\left(\cos{\mu}-1\right)/\sin{\mu}.
# $$
# Эти величины и есть параметры эллипса Флоке. Оставшуюся величину $\varepsilon$ необходимо подобрать так, чтобы эллипс Флоке описывал начальное представление пучка.
#
# Далее для упрощения будем предполагать $d=1$.

# %%
#Определение силы линз для заданного мю
mu = np.pi/8
cosmu = np.cos(mu)
sinmu = np.sin(mu)
fm1 = 2*(1-cosmu)

#Определение коэффициентов эллиса Флоке в начальной точке
bet = 1/sinmu
gam = fm1/sinmu
alf = (cosmu - 1)/sinmu
gambetp = (gam+bet)/2
gambetm = (gam-bet)/2

#Подобранное значение эффективного эмиттанса
eps = 22

# %% [markdown]
# ***Построение эллипса Флоке по его параметрам***
#
# Для <a href="ellipse.html">реализации</a> построения эллипса Флоке воспользуемся спектральным разложением матрицы квадратичной формы.

# %%
#Расчет промежуточных величин для построения эллипса Флоке
lam1 = gambetp + np.sqrt(gambetp**2-1)
lam2 = gambetp - np.sqrt(gambetp**2-1)

a1 = np.sqrt(eps/lam1)
a2 = np.sqrt(eps/lam2)

v1 = -(gam - lam1)/alf
v2 = -(gam - lam2)/alf
P0_11 = 1/np.sqrt(1+v1**2)
P0_12 = 1/np.sqrt(1+v2**2)
P0_21 = v1/np.sqrt(1+v1**2)
P0_22 = v2/np.sqrt(1+v2**2)

#Расчет точек вдоль эллипса Флоке
NEllmax = 100
Teta = [2*np.pi*k/NEllmax for k in range(NEllmax+1)]

EllPoints = [(P0_11*a1*np.cos(T) + P0_12*a2*np.sin(T),
              P0_21*a1*np.cos(T) + P0_22*a2*np.sin(T)) for T in Teta]


#Построение графика эллипса Флоке
EllCurve = hv.Curve( (EllPoints), label='Floquet ellipse' ).opts(color="red")

# %% [markdown]
# ***Учёт нелинейности линзы***
#
# Если в тонкой линзе присутствует сферическая аберрация, то наклон траектории частицы на её выходе можно выразить через входные координату и наклон следующим образом:
# $$
# x'=x'_0-\frac{x_0}{f}\left(1+c{x_0^2}\right).
# $$
# Коэффициент $c$ определяет величину нелинейности. Матрица линзы уже оказывается зависимой от $x$.
#
# Используя указанные матрицы, можно через каждый период восстанавливать $x$ и $x'$ для каждой частицы ансамбля, попутно вычисляя величину среднеквадратичного эмиттанса.

# %%
#Задание коэффициента нелинейности и рассчитываемого числа периодов
c = 0.003
#c = 0.03 #№Здесь уже проявляются интересные нелинейности!!!
Nturns = 4*100

#Задание числа шагов для вывода фазового портрета пучка
Nplots = 11
Nt_to_p = np.arange(0,Nturns+1,int(Nturns/(Nplots-1)))

#Задание числа шагов для построения графика зависимоси среднеквадратичного эмиттанса
#от числа пройденных периодов
Nempts = 41
Nt_to_e = np.arange(0,Nturns+1,int(Nturns/(Nempts-1)))

eps_rms=[]       #Список для хранения величин среднеквадратичного эмиттанса
points_dict = {} #Словарь для хранения фазовых портретов

P=P0.copy()      #Инициализируем распределение точек по начальному
#P=P0            #Особенность Python - так мы только делаем ещё одну ссылку на массив, а не делаем новый массив
                 #Если сделаем так, то при запуске тольк данной ячейки повтороно мы как-бы продолжим идти вдоль канала

#Задание матрицы пустого промежутка
M0 = np.array([[ 1, 1],
               [ 0, 1]])

#Расчет матрицы тонкой линзы с учётом нелинейности
def MF(x):
    return np.array([[ 1,               0],
                     [ -fm1*(1+c*x**2), 1]])

#Собственно цикл по периодам, внутри него цикл по частицам
for k in range(Nturns+1):    
    if k in Nt_to_p:
        points_dict[k] = hv.Points((P))
        
    if k in Nt_to_e:
        eps_rms.append(calc_eps_rms(P))
        
    for l in range(N):
        M = np.matmul(M0, MF(P[l][0]))
        P[l] = np.matmul(M, P[l])

#Построение графиков - фазовых поретретов пучка при различных значениях числа пройденных периодов
phase_map = hv.HoloMap(points_dict, hv.Dimension(('Nturns')))

#Вывод построенных графиков в одном окне
overlay_graphs = (phase_map*EllCurve).opts(width=500, height=500)
overlay_graphs.opts(legend_position='bottom_right')
# Out:
# :HoloMap   [Nturns]
#    :Overlay
#       .Points.I              :Points   [x,y]
#       .Curve.Floquet_ellipse :Curve   [x]   (y)

# %% [markdown]
# ***Возрастание эмиттанса (emittance dilution)***
#
# По результатам растёта построим график возрастания среднеквадратичного эмиттанса с ростом числа пройденных периодов.

# %%
#Вывод графика зависимоси среднеквадратичного эмиттанса от числа пройденных периодов,
#сравнение с величиной эффективного эмиттанса
print ("Effective emitance = ", eps)
rms_plot = hv.Curve((Nt_to_e,eps_rms), "Nturns", "Eps_rms").opts(tools=['hover'], show_grid=True)
rms_plot
# Out:
# Effective emitance =  22
# :Curve   [Nturns]   (Eps_rms)

# %% [markdown]
# Как мы видим, с ростом числа пройденных периодов среднеквадратичный эмиттанс выходит на какую-то постоянную величину. Будучи умноженной на 4, эта величина всё равно оказывается меньше эффективного эмиттанса. Дело в том, что коэфициент 4 связывает между собой среднеквадратичный и обычный эмиттансы только для однородно заполненного эллипса, в нашем же случае пучок заполняет эллипс Флоке неоднородно, в центре его плотность выше, чем на краях.
# <div class = "alert alert-block alert-info">
# Интересно, можно ли как-нибудь рассчитать величину, на котороую выходит среднеквадратичный эмиттанс?
# </div>

# %%
# !jupyter nbconvert --to HTML --no-input --TagRemovePreprocessor.remove_cell_tags='{"hide_cell"}' fo_channel_noniinear_dynamics.ipynb
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\traitlets\traitlets.py:2202: FutureWarning: Supporting extra quotes around strings is deprecated in traitlets 5.0. You can use 'hide_cell' instead of "'hide_cell'" if you require traitlets >=5.
#   warn(
# [NbConvertApp] Converting notebook fo_channel_noniinear_dynamics.ipynb to HTML
# C:\ProgramData\Anaconda3\lib\site-packages\nbconvert\filters\widgetsdatatypefilter.py:69: UserWarning: Your element with mimetype(s) dict_keys([]) is not able to be represented.
#   warn("Your element with mimetype(s) {mimetypes}"
# [NbConvertApp] Writing 5037915 bytes to fo_channel_noniinear_dynamics.html
